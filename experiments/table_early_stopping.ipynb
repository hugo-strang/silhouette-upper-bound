# %%
"""
This file generates tables that show how the upper bound can enable early sopping of ASW based optimisation loops.

Notes: 
    - The unlabeled datasets are available at https://archive.ics.uci.edu/
    - The labeled datasets are available at https://github.com/deric/clustering-benchmark/tree/master/src/main/resources/datasets/real-world 
"""
# Out:
# '\nThis file generates tables that show how the upper bound can enable early sopping of ASW based optimisation loops.\n\nNotes: \n    - The unlabeled datasets are available at https://archive.ics.uci.edu/\n    - The labeled datasets are available at https://github.com/deric/clustering-benchmark/tree/master/src/main/resources/datasets/real-world \n'

# %%
import os 
import numpy as np
import utils

# %%
logger = utils.get_logger(__name__)

# %%
def table_row(data: np.ndarray, dataset: str, k_range: range = range(2, 16), epsilon: float = 0.15, metric: str = "euclidean"):

    logger.info(f"\nDistance metric: {metric}")

    n = data.shape[0]

    if n <= 300:
        k_range = range(2, 31)
        epsilon = 0.35

    ub_dict = utils.get_upper_bound(data=data, metric=metric)

    dissimilarity_matrix = utils.data_to_distance_matrix(data=data, metric=metric)

    kmeans_dict = utils.asw_optimization(algorithm=utils.algorithm_kmeans,
                        data=data,
                        k_range=k_range,
                        asw_metric=metric,
                        ub_reference=ub_dict["ub"],
                        epsilon=epsilon
                    )

    kmedoids_dict = utils.asw_optimization(algorithm=utils.algorithm_kmedoids,
                                             data=dissimilarity_matrix,
                                             k_range=k_range,
                                             asw_metric="precomputed",
                                             ub_reference=ub_dict["ub"],
                                             epsilon=epsilon
                                             )
    
    kmeans_wcre = (ub_dict["ub"] - kmeans_dict["best_score"]) / ub_dict["ub"]
    kmedoids_wcre = (ub_dict["ub"] - kmedoids_dict["best_score"]) / ub_dict["ub"]

    return [
        dataset,
        str(k_range),
        str(epsilon),
        f"${kmeans_dict['best_score']:.3f}$",
        f"${kmedoids_dict['best_score']:.3f}$",
        ub_dict["ub"],
        f"{len(utils.Counter(kmeans_dict['best_labels']))}",
        f"{len(utils.Counter(kmedoids_dict['best_labels']))}",
        kmeans_wcre,
        kmedoids_wcre,
        str(kmeans_dict["stopped_early"]),
        str(kmedoids_dict["stopped_early"]),
    ]

# %%
def table(dataset_list: list, data_type: str = "unlabeled"):
    """
    Print table in terminal.
    """

    headers = [
        "Dataset",
        "K cand.",
        "epsilon",
        "Best ASW Kmeans",
        "Best ASW Kmedoids",
        "UB",
        "Best K Kmeans",
        "Best K Kmedoids",
        "Worst case relative error Kmeans",
        "Worst case relative error Kmedoids",
        "Early stop Kmeans",
        "Early stop Kmeans",
    ]

    lines = []

    # Format header
    header_line = "| " + " | ".join(headers) + " |"
    lines.append(header_line)
    separator = "| " + " | ".join(["---"] * len(headers)) + " |"
    lines.append(separator)

    for dataset in dataset_list:

        if data_type == "unlabeled":
            if dataset == "conference_papers":
                data = utils.load_unlabeled_data(dataset=dataset, transpose=True)
            else:
                data = utils.load_unlabeled_data(dataset=dataset)
            row = table_row(data=data, dataset=dataset)

        elif data_type == "labeled":
            data = dataset["X"]
            row = table_row(data=data, dataset=dataset["name"])

        lines.append(
            " & ".join(
                f"${cell:.3f}$" if type(cell) is not str else f"{cell}" for cell in row
            )
            + " \\\ "
        )

    # Print table to terminal
    print("\nTABLE\n")
    for line in lines:
        print(line)

# %%
# -------------------------------------------------
# Unlabeled Datasets
# -------------------------------------------------
dataset_list = [
        "religious_texts",
        "ceramic", 
        "conference_papers", 
        "rna", 
    ]

table(dataset_list=dataset_list)
# Out:
# 2025-09-03 10:56:01 | utils | INFO | ==== Running dataset: religious_texts ====
#
# 2025-09-03 10:56:01 | utils | INFO | Data shape: (590, 8266)
# 2025-09-03 10:56:01 | utils | INFO | Data shape (zeros removed): (589, 8266)
# 2025-09-03 10:56:01 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 10:56:02 | utils | INFO | Computing upper bound
# 2025-09-03 10:56:02 | utils | INFO | UB: 0.8463322667605195
# 2025-09-03 10:56:02 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:31<00:00,  2.27s/it]
# 2025-09-03 10:56:34 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [17:34<00:00, 75.29s/it]
# 2025-09-03 11:14:08 | utils | INFO | ==== Running dataset: ceramic ====
#
# 2025-09-03 11:14:08 | utils | INFO | Data shape: (88, 17)
# 2025-09-03 11:14:08 | utils | INFO | Data shape (zeros removed): (88, 17)
# 2025-09-03 11:14:08 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:14:08 | utils | INFO | Computing upper bound
# 2025-09-03 11:14:08 | utils | INFO | UB: 0.8549557176260866
# 2025-09-03 11:14:08 | utils | INFO | Optimizing ASW
#   0%|          | 0/29 [00:00<?, ?it/s]2025-09-03 11:14:08 | utils | INFO | Stopping early!
#   0%|          | 0/29 [00:00<?, ?it/s]
# 2025-09-03 11:14:08 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [00:05<00:00,  5.31it/s]
# 2025-09-03 11:14:14 | utils | INFO | ==== Running dataset: conference_papers ====
#
# 2025-09-03 11:14:17 | utils | INFO | Data shape: (5811, 11463)
# 2025-09-03 11:14:17 | utils | INFO | Data shape (zeros removed): (5804, 11463)
# 2025-09-03 11:14:17 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:14:20 | utils | INFO | Computing upper bound
# 2025-09-03 11:14:21 | utils | INFO | UB: 0.4388240669826662
# 2025-09-03 11:14:24 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [01:17<00:00,  5.56s/it]
# 2025-09-03 11:15:42 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [01:22<00:00,  5.92s/it]
# 2025-09-03 11:17:05 | utils | INFO | ==== Running dataset: rna ====
#
# 2025-09-03 11:17:08 | utils | INFO | Data shape: (801, 20531)
# 2025-09-03 11:17:08 | utils | INFO | Data shape (zeros removed): (801, 20531)
# 2025-09-03 11:17:08 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:17:09 | utils | INFO | Computing upper bound
# 2025-09-03 11:17:09 | utils | INFO | UB: 0.41947765108571256
# 2025-09-03 11:17:09 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:14<00:00,  1.01s/it]
# 2025-09-03 11:17:23 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [21:44<00:00, 93.21s/it]
# TABLE
#
# | Dataset | K cand. | epsilon | Best ASW Kmeans | Best ASW Kmedoids | UB | Best K Kmeans | Best K Kmedoids | Worst case relative error Kmeans | Worst case relative error Kmedoids | Early stop Kmeans | Early stop Kmeans |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# religious_texts & range(2, 16) & 0.15 & $0.428$ & $0.846$ & $0.846$ & 3 & 2 & $0.495$ & $0.000$ & False & False \\
# ceramic & range(2, 31) & 0.35 & $0.584$ & $0.584$ & $0.855$ & 2 & 2 & $0.317$ & $0.317$ & True & False \\
# conference_papers & range(2, 16) & 0.15 & $0.067$ & $0.384$ & $0.439$ & 2 & 2 & $0.847$ & $0.126$ & False & False \\
# rna & range(2, 16) & 0.15 & $0.228$ & $0.230$ & $0.419$ & 6 & 8 & $0.457$ & $0.452$ & False & False \\

# %%
# -------------------------------------------------
# Labeled Datasets
# -------------------------------------------------
dataset_dir = "data/labeled/real_world"

datasets = []
for fname in os.listdir(dataset_dir):
    if fname.endswith(".arff"):
        try:
            path = os.path.join(dataset_dir, fname)
            _, X, _ = utils.load_arff_as_distance_matrix(path, scale=True)

            datasets.append({
                "name": fname.replace(".arff", ""),
                "X": X,
            })
        except:
            continue

dataset_list = datasets[:20]  # pick a subset

logger.info("Datasets processed!")
# Out:
# 2025-09-03 11:39:08 | __main__ | INFO | Datasets processed!

# %%
table(dataset_list=dataset_list, data_type="labeled")
# Out:
# 2025-09-03 11:39:08 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:39:08 | utils | INFO | Computing upper bound
# 2025-09-03 11:39:08 | utils | INFO | UB: 0.7079522637070917
# 2025-09-03 11:39:08 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 16.18it/s]
# 2025-09-03 11:39:09 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [16:06<00:00, 69.04s/it]
# 2025-09-03 11:55:16 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:55:16 | utils | INFO | Computing upper bound
# 2025-09-03 11:55:16 | utils | INFO | UB: 0.8538590675108088
# 2025-09-03 11:55:16 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 26.88it/s]
# 2025-09-03 11:55:16 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [02:14<00:00,  9.64s/it]
# 2025-09-03 11:57:31 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:57:31 | utils | INFO | Computing upper bound
# 2025-09-03 11:57:31 | utils | INFO | UB: 0.6260440460708323
# 2025-09-03 11:57:31 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [00:00<00:00, 119.94it/s]
# 2025-09-03 11:57:32 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [01:15<00:00,  2.60s/it]
# 2025-09-03 11:58:47 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 11:58:47 | utils | INFO | Computing upper bound
# 2025-09-03 11:58:47 | utils | INFO | UB: 0.8440281408817187
# 2025-09-03 11:58:47 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 21.27it/s]
# 2025-09-03 11:58:48 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [24:33<00:00, 105.23s/it]
# 2025-09-03 12:23:21 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:23:21 | utils | INFO | Computing upper bound
# 2025-09-03 12:23:21 | utils | INFO | UB: 0.6911749153016913
# 2025-09-03 12:23:21 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 51.57it/s]
# 2025-09-03 12:23:21 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [02:57<00:00, 12.70s/it]
# 2025-09-03 12:26:19 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:26:19 | utils | INFO | Computing upper bound
# 2025-09-03 12:26:19 | utils | INFO | UB: 0.8387531876625399
# 2025-09-03 12:26:19 | utils | INFO | Optimizing ASW
#  79%|███████▉  | 23/29 [00:00<00:00, 111.66it/s]2025-09-03 12:26:20 | utils | INFO | Stopping early!
#  97%|█████████▋| 28/29 [00:00<00:00, 122.88it/s]
# 2025-09-03 12:26:20 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [00:05<00:00,  5.16it/s]
# 2025-09-03 12:26:25 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:26:25 | utils | INFO | Computing upper bound
# 2025-09-03 12:26:25 | utils | INFO | UB: 0.8775099253138198
# 2025-09-03 12:26:25 | utils | INFO | Optimizing ASW
#   0%|          | 0/29 [00:00<?, ?it/s]2025-09-03 12:26:25 | utils | INFO | Stopping early!
#   0%|          | 0/29 [00:00<?, ?it/s]
# 2025-09-03 12:26:25 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [00:27<00:00,  1.07it/s]
# 2025-09-03 12:26:52 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:26:52 | utils | INFO | Computing upper bound
# 2025-09-03 12:26:53 | utils | INFO | UB: 0.9285328552010989
# 2025-09-03 12:26:53 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:01<00:00, 10.74it/s]
# 2025-09-03 12:26:54 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:07<00:00,  1.90it/s]
# 2025-09-03 12:27:02 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:27:02 | utils | INFO | Computing upper bound
# 2025-09-03 12:27:02 | utils | INFO | UB: 0.6091523199330008
# 2025-09-03 12:27:02 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 49.58it/s]
# 2025-09-03 12:27:02 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [02:30<00:00, 10.77s/it]
# 2025-09-03 12:29:33 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:29:33 | utils | INFO | Computing upper bound
# 2025-09-03 12:29:33 | utils | INFO | UB: 0.7373464551463798
# 2025-09-03 12:29:33 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [00:00<00:00, 35.43it/s]
# 2025-09-03 12:29:33 | utils | INFO | Optimizing ASW
# 100%|██████████| 14/14 [14:45<00:00, 63.27s/it]
# 2025-09-03 12:44:19 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:44:19 | utils | INFO | Computing upper bound
# 2025-09-03 12:44:19 | utils | INFO | UB: 0.5930882644804122
# 2025-09-03 12:44:19 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [00:00<00:00, 79.28it/s]
# 2025-09-03 12:44:19 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [03:50<00:00,  7.96s/it]
# 2025-09-03 12:48:10 | __main__ | INFO |
# Distance metric: euclidean
# 2025-09-03 12:48:10 | utils | INFO | Computing upper bound
# 2025-09-03 12:48:10 | utils | INFO | UB: 0.835157133437014
# 2025-09-03 12:48:10 | utils | INFO | Optimizing ASW
#   0%|          | 0/29 [00:00<?, ?it/s]2025-09-03 12:48:10 | utils | INFO | Stopping early!
#   0%|          | 0/29 [00:00<?, ?it/s]
# 2025-09-03 12:48:10 | utils | INFO | Optimizing ASW
# 100%|██████████| 29/29 [01:48<00:00,  3.73s/it]
# TABLE
#
# | Dataset | K cand. | epsilon | Best ASW Kmeans | Best ASW Kmedoids | UB | Best K Kmeans | Best K Kmedoids | Worst case relative error Kmeans | Worst case relative error Kmedoids | Early stop Kmeans | Early stop Kmeans |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# wdbc & range(2, 16) & 0.15 & $0.345$ & $0.661$ & $0.708$ & 2 & 2 & $0.513$ & $0.067$ & False & False \\
# ecoli & range(2, 16) & 0.15 & $0.398$ & $0.836$ & $0.854$ & 4 & 2 & $0.534$ & $0.021$ & False & False \\
# wine & range(2, 31) & 0.35 & $0.285$ & $0.295$ & $0.626$ & 3 & 5 & $0.545$ & $0.529$ & False & False \\
# wisc & range(2, 16) & 0.15 & $0.574$ & $0.574$ & $0.844$ & 2 & 2 & $0.320$ & $0.320$ & False & False \\
# iono & range(2, 16) & 0.15 & $0.293$ & $0.413$ & $0.691$ & 6 & 2 & $0.575$ & $0.402$ & False & False \\
# zoo & range(2, 31) & 0.35 & $0.547$ & $0.616$ & $0.839$ & 30 & 30 & $0.348$ & $0.265$ & True & False \\
# iris & range(2, 31) & 0.35 & $0.580$ & $0.580$ & $0.878$ & 2 & 2 & $0.339$ & $0.339$ & True & False \\
# segment & range(2, 16) & 0.15 & $0.357$ & $0.778$ & $0.929$ & 7 & 2 & $0.615$ & $0.162$ & False & False \\
# dermatology & range(2, 16) & 0.15 & $0.277$ & $0.357$ & $0.609$ & 3 & 2 & $0.545$ & $0.415$ & False & False \\
# balance-scale & range(2, 16) & 0.15 & $0.219$ & $0.209$ & $0.737$ & 8 & 13 & $0.703$ & $0.716$ & False & False \\
# heart-statlog & range(2, 31) & 0.35 & $0.169$ & $0.322$ & $0.593$ & 3 & 2 & $0.716$ & $0.458$ & False & False \\
# thy & range(2, 31) & 0.35 & $0.577$ & $0.734$ & $0.835$ & 2 & 2 & $0.309$ & $0.121$ & True & False \\
